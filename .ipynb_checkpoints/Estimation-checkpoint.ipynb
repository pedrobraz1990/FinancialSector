# %%
# %matplotlib inline

import numpy as np
import pandas as pd

from statsmodels.regression.quantile_regression import QuantReg
import statsmodels.api as sm

pd.set_option('max_rows', 10)

# %% [markdown]
# # Financial Sector - Estimation
#
# All data series were downloaded from the [World Bank Website](http://data.worldbank.org)
#
# * Financial Depth: Domestic credit provided by financial sector (% of GDP) - EXPLANATORY VARIABLE
# * Real GDP Per Capita: GDP per capita, PPP (current international $) - RESPONSE VARIABLE
# * Inflation Rate Inflation, consumer prices (annual %) - CONTROL VARIABLE
# * Merchandise Trade: Merchandise trade (% of GDP) - CONTROL VARIABLE
# * Primary completion rate, total (% of relevant age group) - We opted for this as a education proxy - CONTROL VARIABLE

# %% [markdown]
# ## Load

# %%
df = pd.read_excel('Data.xlsx',None)

# %%
def sortDf(df,key):
    df.drop(['Country Name','Indicator Code','Indicator Name',], axis=1, inplace=True)
    df = pd.DataFrame(df.set_index('Country Code').stack())
    df.columns = [key]
    return df

# %%
dfsList = []
for key in df.keys():
    dfsList.append(sortDf(df[key],key))

# %%
df = pd.concat(dfsList,axis=1)
df
# Out:
#                    MerchanTrade  RealGdpPerCapita  InflationRate  \
# Country Code
# ABW          1960           NaN               NaN            NaN
#              1961           NaN               NaN            NaN
#              1962           NaN               NaN            NaN
#              1963           NaN               NaN            NaN
#              1964           NaN               NaN            NaN
# ...                         ...               ...            ...
# ZWE          2011     72.215785       1523.621784       3.277509
#              2012     66.833044       1679.125594       3.922235
#              2013     57.873718       1743.210783       1.631622
#              2014     51.164230       1798.059812      -0.217286
#              2015     48.338968       1793.586092      -2.398710
#
#                    GrossCapital         Pop  PrimaryRateCompletion  \
# Country Code
# ABW          1960           NaN     54208.0                    NaN
#              1961           NaN     55435.0                    NaN
#              1962           NaN     56226.0                    NaN
#              1963           NaN     56697.0                    NaN
#              1964           NaN     57029.0                    NaN
# ...                         ...         ...                    ...
# ZWE          2011     22.392920  14255592.0                    NaN
#              2012     13.612891  14565482.0              89.225418
#              2013     13.033016  14898092.0              90.249062
#              2014     13.236799  15245855.0                    NaN
#              2015     13.239581  15602751.0                    NaN
#
#                    FinancDepth
# Country Code
# ABW          1960          NaN
#              1961          NaN
#              1962          NaN
#              1963          NaN
#              1964          NaN
# ...                        ...
# ZWE          2011          NaN
#              2012          NaN
#              2013          NaN
#              2014          NaN
#              2015          NaN
#
# [14628 rows x 7 columns]

# %% [markdown]
# # Selecting Our Sample
#
# We will try to use a similar time window of 15 years, thus from 2000 to 2015

# %%
df = df.swaplevel()

listOfYears = []
for i in range(1999,2016):
    listOfYears.append(str(i))

df.sort_index(inplace=True)
idx = pd.IndexSlice
df = df.loc[idx[listOfYears,:],:]
df
# Out:
#                    MerchanTrade  RealGdpPerCapita  InflationRate  \
#      Country Code
# 1999 ABW             196.364238               NaN       2.280372
#      AFG                    NaN               NaN            NaN
#      AGO             134.342357       2972.321938     248.195902
#      ALB              44.085370       3684.945153       0.389438
#      AND                    NaN               NaN            NaN
# ...                         ...               ...            ...
# 2015 WSM              50.813106       5922.815359       0.724470
#      YEM                    NaN               NaN            NaN
#      ZAF              59.556919      13165.148024       4.588271
#      ZMB              72.693816       3852.658974      10.100695
#      ZWE              48.338968       1793.586092      -2.398710
#
#                    GrossCapital         Pop  PrimaryRateCompletion  \
#      Country Code
# 1999 ABW              27.723498     89004.0             101.619118
#      AFG                    NaN  19038420.0                    NaN
#      AGO              28.899574  14601983.0                    NaN
#      ALB              22.986393   3108778.0                    NaN
#      AND                    NaN     64161.0                    NaN
# ...                         ...         ...                    ...
# 2015 WSM                    NaN    193228.0                    NaN
#      YEM                    NaN  26832215.0                    NaN
#      ZAF              19.508398  54956920.0                    NaN
#      ZMB                    NaN  16211767.0                    NaN
#      ZWE              13.239581  15602751.0                    NaN
#
#                    FinancDepth
#      Country Code
# 1999 ABW             44.554334
#      AFG                   NaN
#      AGO              7.219949
#      ALB             50.112177
#      AND                   NaN
# ...                        ...
# 2015 WSM             76.109221
#      YEM                   NaN
#      ZAF            180.050114
#      ZMB             29.448022
#      ZWE                   NaN
#
# [4469 rows x 7 columns]

# %% [markdown]
# Now we have to find countries with complete data

# %%
df = df.swaplevel().sort_index()

# %%
pd.set_option('max_rows', 500)
~(df.isnull().groupby(level="Country Code").any().any(axis=1))
# Out:
# Country Code
# ABW    False
# AFG    False
# AGO    False
# ALB    False
# AND    False
# ARB    False
# ARE    False
# ARG    False
# ARM    False
# ASM    False
# ATG    False
# AUS    False
# AUT    False
# AZE    False
# BDI    False
# BEL    False
# BEN    False
# BFA    False
# BGD    False
# BGR    False
# BHR    False
# BHS    False
# BIH    False
# BLR    False
# BLZ    False
# BMU    False
# BOL    False
# BRA    False
# BRB    False
# BRN    False
# BTN    False
# BWA    False
# CAF    False
# CAN    False
# CEB    False
# CHE    False
# CHI    False
# CHL    False
# CHN    False
# CIV    False
# CMR    False
# COD    False
# COG    False
# COL    False
# COM    False
# CPV    False
# CRI    False
# CSS    False
# CUB    False
# CUW    False
# CYM    False
# CYP    False
# CZE    False
# DEU    False
# DJI    False
# DMA    False
# DNK    False
# DOM    False
# DZA    False
# EAP    False
# EAR    False
# EAS    False
# ECA    False
# ECS    False
# ECU    False
# EGY    False
# EMU    False
# ERI    False
# ESP    False
# EST    False
# ETH    False
# EUU    False
# FCS    False
# FIN    False
# FJI    False
# FRA    False
# FRO    False
# FSM    False
# GAB    False
# GBR    False
# GEO    False
# GHA    False
# GIB    False
# GIN    False
# GMB    False
# GNB    False
# GNQ    False
# GRC    False
# GRD    False
# GRL    False
# GTM    False
# GUM    False
# GUY    False
# HIC    False
# HKG    False
# HND    False
# HPC    False
# HRV    False
# HTI    False
# HUN    False
# IBD    False
# IBT    False
# IDA    False
# IDB    False
# IDN    False
# IDX    False
# IMN    False
# IND    False
# IRL    False
# IRN    False
# IRQ    False
# ISL    False
# ISR    False
# ITA    False
# JAM    False
# JOR    False
# JPN    False
# KAZ    False
# KEN    False
# KGZ    False
# KHM    False
# KIR    False
# KNA    False
# KOR    False
# KSV    False
# KWT    False
# LAC    False
# LAO    False
# LBN    False
# LBR    False
# LBY    False
# LCA    False
# LCN    False
# LDC    False
# LIC    False
# LIE    False
# LKA    False
# LMC    False
# LMY    False
# LSO    False
# LTE    False
# LTU    False
# LUX    False
# LVA    False
# MAC    False
# MAF    False
# MAR    False
# MCO    False
# MDA    False
# MDG    False
# MDV    False
# MEA    False
# MEX    False
# MHL    False
# MIC    False
# MKD    False
# MLI    False
# MLT    False
# MMR    False
# MNA    False
# MNE    False
# MNG    False
# MNP    False
# MOZ    False
# MRT    False
# MUS    False
# MWI    False
# MYS    False
# NAC    False
# NAM    False
# NCL    False
# NER    False
# NGA    False
# NIC    False
# NLD    False
# NOR    False
# NPL    False
# NRU    False
# NZL    False
# OED    False
# OMN    False
# OSS    False
# PAK    False
# PAN    False
# PER    False
# PHL    False
# PLW    False
# PNG    False
# POL    False
# PRE    False
# PRI    False
# PRK    False
# PRT    False
# PRY    False
# PSE    False
# PSS    False
# PST    False
# PYF    False
# QAT    False
# ROU    False
# RUS    False
# RWA    False
# SAS    False
# SAU    False
# SDN    False
# SEN    False
# SGP    False
# SLB    False
# SLE    False
# SLV    False
# SMR    False
# SOM    False
# SRB    False
# SSA    False
# SSD    False
# SSF    False
# SST    False
# STP    False
# SUR    False
# SVK    False
# SVN    False
# SWE    False
# SWZ    False
# SXM    False
# SYC    False
# SYR    False
# TCA    False
# TCD    False
# TEA    False
# TEC    False
# TGO    False
# THA    False
# TJK    False
# TKM    False
# TLA    False
# TLS    False
# TMN    False
# TON    False
# TSA    False
# TSS    False
# TTO    False
# TUN    False
# TUR    False
# TUV    False
# TZA    False
# UGA    False
# UKR    False
# UMC    False
# URY    False
# USA    False
# UZB    False
# VCT    False
# VEN    False
# VGB    False
# VIR    False
# VNM    False
# VUT    False
# WLD    False
# WSM    False
# YEM    False
# ZAF    False
# ZMB    False
# ZWE    False
# dtype: bool

# %%
df.loc["USA"]
# Out:
#       MerchanTrade  RealGdpPerCapita  InflationRate  GrossCapital  \
# 1999     18.168982      34620.928899       2.188027     23.317953
# 2000     19.846980      36449.855116       3.376857     23.568925
# 2001     17.965653      37273.618103       2.826171     22.051491
# 2002     17.247375      38166.037841       1.586032     21.576522
# 2003     17.616881      39677.198348       2.270095     21.659967
# 2004     19.067770      41921.809762       2.677237     22.526727
# 2005     20.114886      44307.920585       3.392747     23.222953
# 2006     21.247602      46437.067117       3.225944     23.333015
# 2007     21.886185      48061.537661       2.852672     22.351353
# 2008     23.486835      48401.427340       3.839100     20.786244
# 2009     18.457500      47001.555350      -0.355546     17.512933
# 2010     21.702741      48374.086793       1.640043     18.394598
# 2011     24.156140      49781.800656       3.156842     18.544756
# 2012     24.030738      51433.047090       2.069337     19.350606
# 2013     23.456852      52660.295105       1.464833     19.547918
# 2014     23.247996      54398.460009       1.622223     19.920712
# 2015     21.245115      55836.792631       0.118627     20.237649
#
#               Pop  PrimaryRateCompletion  FinancDepth
# 1999  279040000.0                    NaN   201.263956
# 2000  282162411.0                    NaN   190.962275
# 2001  284968955.0                    NaN   198.587775
# 2002  287625193.0                    NaN   191.785229
# 2003  290107933.0                    NaN   206.579807
# 2004  292805298.0                    NaN   212.918016
# 2005  295516599.0                    NaN   216.329179
# 2006  298379912.0                    NaN   226.324174
# 2007  301231207.0                    NaN   235.894430
# 2008  304093966.0                    NaN   216.762891
# 2009  306771529.0                    NaN   234.553607
# 2010  309346863.0                    NaN   231.450855
# 2011  311718857.0                    NaN   230.561426
# 2012  314102623.0                    NaN   232.965775
# 2013  316427395.0                    NaN   247.635573
# 2014  318907401.0                    NaN   251.779153
# 2015  321418820.0                    NaN   238.286337

# %% [markdown]
# It appears that Primary Rate completion is not filled for many countries. Thus we will drop it for now.

# %%
df.drop('PrimaryRateCompletion',axis=1,inplace=True)

# %%
sampleCountries = ~(df.isnull().groupby(level="Country Code").any().any(axis=1))

# %%
sampleCountries = sampleCountries[sampleCountries==True].index
len(sampleCountries)
# Out:
# 101

# %% [markdown]
# We have 101 countries in the sample. Which is more than the original paper with 77. We have our samples.

# %%
df = df.loc[list(sampleCountries)]

# %% [markdown]
# # Data Manipulations
#
# ## Calculate GDP Growth Rate
#
# Since we only have the absolute value of the variable

# %%
df['GdpRate'] = df['RealGdpPerCapita'].groupby(level="Country Code").shift(0) / df['RealGdpPerCapita'].groupby(level="Country Code").shift(1)

# %% [markdown]
# ## Ln() of Inflation

# %%
df['LnInflation'] = np.log(df['InflationRate'] /  100)

# %%
df.head()
# Out:
#                    MerchanTrade  RealGdpPerCapita  InflationRate  \
# Country Code
# AGO          1999    134.342357       2972.321938     248.195902
#              2000    120.059565       3036.559728     324.996872
#              2001    108.694391       3131.995858     152.561022
#              2002     96.724531       2858.897069     108.897436
#              2003    105.631501       2961.964572      98.223718
#
#                    GrossCapital         Pop  FinancDepth   GdpRate  \
# Country Code
# AGO          1999     28.899574  14601983.0     7.219949       NaN
#              2000     12.755027  15058638.0   -14.755435  1.021612
#              2001     13.450919  15562791.0    -0.319143  1.031429
#              2002     37.296420  16109696.0     5.004125  0.912804
#              2003     38.228106  16691395.0     6.626453  1.036051
#
#                    LnInflation
# Country Code
# AGO          1999     0.909048
#              2000     1.178645
#              2001     0.422394
#              2002     0.085236
#              2003    -0.017922

# %% [markdown]
# # Estimation

# %%
finalSample = df.groupby(level='Country Code').mean()
finalSample.head()
# Out:
#               MerchanTrade  RealGdpPerCapita  InflationRate  GrossCapital  \
# Country Code
# AGO              94.360654       5076.298701      65.629633     21.209882
# ALB              47.337332       7593.348105       2.463691     33.164009
# ARM              54.208403       5432.326964       3.937327     26.849415
# ATG              53.736358      19611.929659       1.949115     28.899016
# AUS              33.914163      35904.048442       2.794667     26.982632
#
#                        Pop  FinancDepth   GdpRate  LnInflation
# Country Code
# AGO           1.940390e+07    10.225204  1.061294    -1.261715
# ALB           2.977762e+06    58.261895  1.073425    -4.065030
# ARM           3.012460e+06    21.674713  1.092614    -3.416228
# ATG           8.438524e+04    85.296767  1.031085    -4.005236
# AUS           2.114647e+07   131.351110  1.037834    -3.633616

# %% [markdown]
# ## Q=0.1

# %%
model = QuantReg(finalSample['GdpRate'], sm.add_constant(finalSample[['FinancDepth','RealGdpPerCapita','MerchanTrade','LnInflation']]))
fitted = model.fit(q=0.1)
print(fitted.summary())
# Out:
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:                GdpRate   Pseudo R-squared:              0.09111
# Model:                       QuantReg   Bandwidth:                     0.01315
# Method:                 Least Squares   Sparsity:                      0.04976
# Date:                Mon, 05 Dec 2016   No. Observations:                  101
# Time:                        16:51:41   Df Residuals:                       96
#                                         Df Model:                            4
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const                1.0476      0.010    101.889      0.000         1.027     1.068
# FinancDepth      -6.389e-05   3.87e-05     -1.649      0.102        -0.000   1.3e-05
# RealGdpPerCapita  1.231e-07   1.47e-07      0.836      0.405     -1.69e-07  4.16e-07
# MerchanTrade      9.456e-05   7.79e-05      1.214      0.228     -6.01e-05     0.000
# LnInflation          0.0052      0.003      1.642      0.104        -0.001     0.011
# ====================================================================================
#
# The condition number is large, 1.02e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Q=0.25

# %%
model = QuantReg(finalSample['GdpRate'], sm.add_constant(finalSample[['FinancDepth','RealGdpPerCapita','MerchanTrade','LnInflation']]))
fitted = model.fit(q=0.25)
print(fitted.summary())
# Out:
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:                GdpRate   Pseudo R-squared:               0.1952
# Model:                       QuantReg   Bandwidth:                     0.01418
# Method:                 Least Squares   Sparsity:                      0.03616
# Date:                Mon, 05 Dec 2016   No. Observations:                  101
# Time:                        16:51:41   Df Residuals:                       96
#                                         Df Model:                            4
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const                1.0617      0.009    124.656      0.000         1.045     1.079
# FinancDepth      -5.318e-05   3.46e-05     -1.537      0.127        -0.000  1.55e-05
# RealGdpPerCapita  2.064e-07   1.33e-07      1.549      0.125     -5.81e-08  4.71e-07
# MerchanTrade       6.43e-05   5.23e-05      1.230      0.222     -3.94e-05     0.000
# LnInflation          0.0077      0.003      2.776      0.007         0.002     0.013
# ====================================================================================
#
# The condition number is large, 1.02e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Q=0.5

# %%
model = QuantReg(finalSample['GdpRate'], sm.add_constant(finalSample[['FinancDepth','RealGdpPerCapita','MerchanTrade','LnInflation']]))
fitted = model.fit(q=0.5)
print(fitted.summary())
# Out:
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:                GdpRate   Pseudo R-squared:               0.2021
# Model:                       QuantReg   Bandwidth:                     0.01262
# Method:                 Least Squares   Sparsity:                      0.03407
# Date:                Mon, 05 Dec 2016   No. Observations:                  101
# Time:                        16:51:41   Df Residuals:                       96
#                                         Df Model:                            4
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const                1.0728      0.008    128.339      0.000         1.056     1.089
# FinancDepth      -8.247e-05   3.91e-05     -2.107      0.038        -0.000 -4.76e-06
# RealGdpPerCapita  2.584e-07   1.61e-07      1.604      0.112     -6.14e-08  5.78e-07
# MerchanTrade         0.0001   4.06e-05      2.708      0.008      2.94e-05     0.000
# LnInflation          0.0097      0.003      3.523      0.001         0.004     0.015
# ====================================================================================
#
# The condition number is large, 1.02e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Q=0.75

# %%
model = QuantReg(finalSample['GdpRate'], sm.add_constant(finalSample[['FinancDepth','RealGdpPerCapita','MerchanTrade','LnInflation']]))
fitted = model.fit(q=0.75)
print(fitted.summary())
# Out:
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:                GdpRate   Pseudo R-squared:               0.1876
# Model:                       QuantReg   Bandwidth:                     0.01349
# Method:                 Least Squares   Sparsity:                      0.05106
# Date:                Mon, 05 Dec 2016   No. Observations:                  101
# Time:                        16:51:41   Df Residuals:                       96
#                                         Df Model:                            4
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const                1.0695      0.010    109.753      0.000         1.050     1.089
# FinancDepth         -0.0002   6.66e-05     -2.914      0.004        -0.000 -6.19e-05
# RealGdpPerCapita  3.669e-07   2.89e-07      1.271      0.207     -2.06e-07   9.4e-07
# MerchanTrade         0.0002   4.64e-05      3.262      0.002      5.93e-05     0.000
# LnInflation          0.0040      0.003      1.253      0.213        -0.002     0.010
# ====================================================================================
#
# The condition number is large, 1.02e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Q=0.9

# %%
model = QuantReg(finalSample['GdpRate'], sm.add_constant(finalSample[['FinancDepth','RealGdpPerCapita','MerchanTrade','LnInflation']]))
fitted = model.fit(q=0.9)
print(fitted.summary())
# Out:
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:                GdpRate   Pseudo R-squared:               0.1843
# Model:                       QuantReg   Bandwidth:                     0.01577
# Method:                 Least Squares   Sparsity:                       0.1181
# Date:                Mon, 05 Dec 2016   No. Observations:                  101
# Time:                        16:51:41   Df Residuals:                       96
#                                         Df Model:                            4
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const                1.0830      0.019     56.909      0.000         1.045     1.121
# FinancDepth         -0.0002      0.000     -1.157      0.250        -0.000     0.000
# RealGdpPerCapita  2.108e-07    7.5e-07      0.281      0.779     -1.28e-06   1.7e-06
# MerchanTrade      4.989e-05   9.82e-05      0.508      0.612        -0.000     0.000
# LnInflation          0.0013      0.006      0.215      0.830        -0.010     0.013
# ====================================================================================
#
# The condition number is large, 1.02e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # OLS

# %%
model = sm.OLS(finalSample['GdpRate'], sm.add_constant(finalSample[['FinancDepth','RealGdpPerCapita','MerchanTrade','LnInflation']]))
fitted = model.fit()
print(fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                GdpRate   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.231
# Method:                 Least Squares   F-statistic:                     8.500
# Date:                Mon, 05 Dec 2016   Prob (F-statistic):           6.49e-06
# Time:                        16:51:41   Log-Likelihood:                 269.84
# No. Observations:                 101   AIC:                            -529.7
# Df Residuals:                      96   BIC:                            -516.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const                1.0713      0.008    127.236      0.000         1.055     1.088
# FinancDepth         -0.0001   3.94e-05     -3.243      0.002        -0.000 -4.96e-05
# RealGdpPerCapita  3.319e-07   1.62e-07      2.045      0.044      9.69e-09  6.54e-07
# MerchanTrade      8.411e-05   4.09e-05      2.055      0.043      2.87e-06     0.000
# LnInflation          0.0071      0.003      2.540      0.013         0.002     0.013
# ==============================================================================
# Omnibus:                       14.103   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               18.047
# Skew:                           0.715   Prob(JB):                     0.000121
# Kurtosis:                       4.498   Cond. No.                     1.02e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.02e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
model = sm.OLS(finalSample['GdpRate'], sm.add_constant(finalSample[['FinancDepth','RealGdpPerCapita','MerchanTrade','LnInflation']]))
fitted = model.fit()
print(fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                GdpRate   R-squared:                       0.137
# Model:                            OLS   Adj. R-squared:                  0.128
# Method:                 Least Squares   F-statistic:                     15.70
# Date:                Mon, 05 Dec 2016   Prob (F-statistic):           0.000140
# Time:                        16:56:10   Log-Likelihood:                 261.97
# No. Observations:                 101   AIC:                            -519.9
# Df Residuals:                      99   BIC:                            -514.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# const           1.0585      0.003    390.229      0.000         1.053     1.064
# FinancDepth    -0.0001   3.12e-05     -3.962      0.000        -0.000 -6.16e-05
# ==============================================================================
# Omnibus:                        7.688   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.021   Jarque-Bera (JB):                7.384
# Skew:                           0.551   Prob(JB):                       0.0249
# Kurtosis:                       3.734   Cond. No.                         130.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
finalSample.plot.scatter("GdpRate","FinancDepth")
